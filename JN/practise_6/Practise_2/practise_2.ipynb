# %%
import numpy as np
import pandas as pd
import seaborn as sns
from sklearn.preprocessing import StandardScaler

# %%
data={
    "Name":pd.Series(["Nikita","Jayant","Pisu","Hritik","isha","Aakansha"]),
    "Division":pd.Series(["A","A","B","C","D","C"]),
    "Marks1":pd.Series([90,100,np.nan,86,92,12]),
    "Marks2":pd.Series([91,10,81,2,20,np.nan])
}
data=pd.DataFrame(data)

# %%
data.head
# Out:
# <bound method NDFrame.head of        Name Division  Marks1  Marks2
# 0    Nikita        A    90.0    91.0
# 1    Jayant        A   100.0    10.0
# 2      Pisu        B     NaN    81.0
# 3    Hritik        C    86.0     2.0
# 4      isha        D    92.0    20.0
# 5  Aakansha        C    12.0     NaN>

# %%
data.sample(6)
# Out:
#        Name Division  Marks1  Marks2
# 0    Nikita        A    90.0    91.0
# 3    Hritik        C    86.0     2.0
# 1    Jayant        A   100.0    10.0
# 4      isha        D    92.0    20.0
# 2      Pisu        B     NaN    81.0
# 5  Aakansha        C    12.0     NaN

# %%
data.info
# Out:
# <bound method DataFrame.info of        Name Division  Marks1  Marks2
# 0    Nikita        A    90.0    91.0
# 1    Jayant        A   100.0    10.0
# 2      Pisu        B     NaN    81.0
# 3    Hritik        C    86.0     2.0
# 4      isha        D    92.0    20.0
# 5  Aakansha        C    12.0     NaN>

# %%
data.describe()
# Out:
#            Marks1     Marks2
# count    5.000000   5.000000
# mean    76.000000  40.800000
# std     36.138622  41.901074
# min     12.000000   2.000000
# 25%     86.000000  10.000000
# 50%     90.000000  20.000000
# 75%     92.000000  81.000000
# max    100.000000  91.000000

# %%
data.dtypes
# Out:
# Name         object
# Division     object
# Marks1      float64
# Marks2      float64
# dtype: object

# %%
data.columns
# Out:
# Index(['Name', 'Division', 'Marks1', 'Marks2'], dtype='object')

# %%
data.isna().sum()
# Out:
# Name        0
# Division    0
# Marks1      1
# Marks2      1
# dtype: int64

# %%
data["Marks1"]=data["Marks1"].fillna(data["Marks1"].mean())

# %%
data
# Out:
#        Name Division                                             Marks1  \
# 0    Nikita        A  <bound method Series.notna of 0     90.0\n1   ...
# 1    Jayant        A  <bound method Series.notna of 0     90.0\n1   ...
# 2      Pisu        B  <bound method Series.notna of 0     90.0\n1   ...
# 3    Hritik        C  <bound method Series.notna of 0     90.0\n1   ...
# 4      isha        D  <bound method Series.notna of 0     90.0\n1   ...
# 5  Aakansha        C  <bound method Series.notna of 0     90.0\n1   ...
#
#                                               Marks2
# 0  <bound method Series.notna of 0    <bound meth...
# 1  <bound method Series.notna of 0    <bound meth...
# 2  <bound method Series.notna of 0    <bound meth...
# 3  <bound method Series.notna of 0    <bound meth...
# 4  <bound method Series.notna of 0    <bound meth...
# 5  <bound method Series.notna of 0    <bound meth...

# %%
data["Marks2"]=data["Marks2"].notna()

# %%
data
# Out:
#        Name Division                                             Marks1  \
# 0    Nikita        A  <bound method Series.notna of 0     90.0\n1   ...
# 1    Jayant        A  <bound method Series.notna of 0     90.0\n1   ...
# 2      Pisu        B  <bound method Series.notna of 0     90.0\n1   ...
# 3    Hritik        C  <bound method Series.notna of 0     90.0\n1   ...
# 4      isha        D  <bound method Series.notna of 0     90.0\n1   ...
# 5  Aakansha        C  <bound method Series.notna of 0     90.0\n1   ...
#
#    Marks2
# 0    True
# 1    True
# 2    True
# 3    True
# 4    True
# 5    True

# %%
data["Marks1"]=data["Marks1"].notna()

# %%
data
# Out:
#        Name Division  Marks1  Marks2
# 0    Nikita        A    True    True
# 1    Jayant        A    True    True
# 2      Pisu        B    True    True
# 3    Hritik        C    True    True
# 4      isha        D    True    True
# 5  Aakansha        C    True    True

# %%
data = {
    'name': pd.Series(['Alice', 'Bob', 'Charlie', 'David', 'Emma', 'Frank', 'Grace', 'Henry', 'Ivy', 'Jack',
                       'Katie', 'Liam', 'Mia', 'Nate', 'Olivia', 'Peter', 'Quinn', 'Rachel', 'Sam', 'Tyler']),
    'division': pd.Series(['A', 'B', 'A', 'C', 'B', 'A', 'B', 'C', 'B', 'A', 'C', 'B', 'A', 'C', 'B', 'A', 'C',
                           'B', 'A', 'C']),
    'marks1': pd.Series([70, 80, 85, 90, 95, 65, 75, 60, 50, 85, np.nan, 55, 80, 70, 75, 40, 90, 80, 85, 65]),
    'marks2': pd.Series([60, 70, 75, 80, 85, 55, 65, 50, 40, 75, 80, 45, 70, 60, np.nan, 30, 80, 70, 75, 55]),
    'marks3': pd.Series([5, 60, 65, 70, 75, 45, 55, 40, 30, 65, 70, 35, 60, 50, 55, 20, 70, 60, np.nan, 45])
}

# Create the dataframe
df = pd.DataFrame(data)

# %%
df
# Out:
#        name division  marks1  marks2  marks3
# 0     Alice        A    70.0    60.0     5.0
# 1       Bob        B    80.0    70.0    60.0
# 2   Charlie        A    85.0    75.0    65.0
# 3     David        C    90.0    80.0    70.0
# 4      Emma        B    95.0    85.0    75.0
# 5     Frank        A    65.0    55.0    45.0
# 6     Grace        B    75.0    65.0    55.0
# 7     Henry        C    60.0    50.0    40.0
# 8       Ivy        B    50.0    40.0    30.0
# 9      Jack        A    85.0    75.0    65.0
# 10    Katie        C     NaN    80.0    70.0
# 11     Liam        B    55.0    45.0    35.0
# 12      Mia        A    80.0    70.0    60.0
# 13     Nate        C    70.0    60.0    50.0
# 14   Olivia        B    75.0     NaN    55.0
# 15    Peter        A    40.0    30.0    20.0
# 16    Quinn        C    90.0    80.0    70.0
# 17   Rachel        B    80.0    70.0    60.0
# 18      Sam        A    85.0    75.0     NaN
# 19    Tyler        C    65.0    55.0    45.0

# %%
df["marks1"]=df["marks1"].notna()

# %%
df
# Out:
#        name division  marks1  marks2  marks3
# 0     Alice        A    True    60.0     5.0
# 1       Bob        B    True    70.0    60.0
# 2   Charlie        A    True    75.0    65.0
# 3     David        C    True    80.0    70.0
# 4      Emma        B    True    85.0    75.0
# 5     Frank        A    True    55.0    45.0
# 6     Grace        B    True    65.0    55.0
# 7     Henry        C    True    50.0    40.0
# 8       Ivy        B    True    40.0    30.0
# 9      Jack        A    True    75.0    65.0
# 10    Katie        C   False    80.0    70.0
# 11     Liam        B    True    45.0    35.0
# 12      Mia        A    True    70.0    60.0
# 13     Nate        C    True    60.0    50.0
# 14   Olivia        B    True     NaN    55.0
# 15    Peter        A    True    30.0    20.0
# 16    Quinn        C    True    80.0    70.0
# 17   Rachel        B    True    70.0    60.0
# 18      Sam        A    True    75.0     NaN
# 19    Tyler        C    True    55.0    45.0

# %%
df=df[df["marks2"].notna()]

# %%
df
# Out:
#        name division  marks1  marks2  marks3
# 0     Alice        A    True    60.0     5.0
# 1       Bob        B    True    70.0    60.0
# 2   Charlie        A    True    75.0    65.0
# 3     David        C    True    80.0    70.0
# 4      Emma        B    True    85.0    75.0
# 5     Frank        A    True    55.0    45.0
# 6     Grace        B    True    65.0    55.0
# 7     Henry        C    True    50.0    40.0
# 8       Ivy        B    True    40.0    30.0
# 9      Jack        A    True    75.0    65.0
# 10    Katie        C   False    80.0    70.0
# 11     Liam        B    True    45.0    35.0
# 12      Mia        A    True    70.0    60.0
# 13     Nate        C    True    60.0    50.0
# 15    Peter        A    True    30.0    20.0
# 16    Quinn        C    True    80.0    70.0
# 17   Rachel        B    True    70.0    60.0
# 18      Sam        A    True    75.0     NaN
# 19    Tyler        C    True    55.0    45.0

# %%
df=df[df["marks3"].notna()]

# %%
df
# Out:
#        name division  marks1  marks2  marks3
# 0     Alice        A    True    60.0     5.0
# 1       Bob        B    True    70.0    60.0
# 2   Charlie        A    True    75.0    65.0
# 3     David        C    True    80.0    70.0
# 4      Emma        B    True    85.0    75.0
# 5     Frank        A    True    55.0    45.0
# 6     Grace        B    True    65.0    55.0
# 7     Henry        C    True    50.0    40.0
# 8       Ivy        B    True    40.0    30.0
# 9      Jack        A    True    75.0    65.0
# 10    Katie        C   False    80.0    70.0
# 11     Liam        B    True    45.0    35.0
# 12      Mia        A    True    70.0    60.0
# 13     Nate        C    True    60.0    50.0
# 15    Peter        A    True    30.0    20.0
# 16    Quinn        C    True    80.0    70.0
# 17   Rachel        B    True    70.0    60.0
# 19    Tyler        C    True    55.0    45.0

# %%
df.isna().sum()
# Out:
# name        0
# division    0
# marks1      0
# marks2      0
# marks3      0
# dtype: int64

# %%
df.isna()
# Out:
#      name  division  marks1  marks2  marks3
# 0   False     False   False   False   False
# 1   False     False   False   False   False
# 2   False     False   False   False   False
# 3   False     False   False   False   False
# 4   False     False   False   False   False
# 5   False     False   False   False   False
# 6   False     False   False   False   False
# 7   False     False   False   False   False
# 8   False     False   False   False   False
# 9   False     False   False   False   False
# 10  False     False   False   False   False
# 11  False     False   False   False   False
# 12  False     False   False   False   False
# 13  False     False   False   False   False
# 15  False     False   False   False   False
# 16  False     False   False   False   False
# 17  False     False   False   False   False
# 19  False     False   False   False   False

# %%
df
# Out:
#        name division  marks1  marks2  marks3
# 0     Alice        A    True    60.0     5.0
# 1       Bob        B    True    70.0    60.0
# 2   Charlie        A    True    75.0    65.0
# 3     David        C    True    80.0    70.0
# 4      Emma        B    True    85.0    75.0
# 5     Frank        A    True    55.0    45.0
# 6     Grace        B    True    65.0    55.0
# 7     Henry        C    True    50.0    40.0
# 8       Ivy        B    True    40.0    30.0
# 9      Jack        A    True    75.0    65.0
# 10    Katie        C   False    80.0    70.0
# 11     Liam        B    True    45.0    35.0
# 12      Mia        A    True    70.0    60.0
# 13     Nate        C    True    60.0    50.0
# 15    Peter        A    True    30.0    20.0
# 16    Quinn        C    True    80.0    70.0
# 17   Rachel        B    True    70.0    60.0
# 19    Tyler        C    True    55.0    45.0

# %%
sns.countplot(data=df,x=df["marks2"])
# Out:
# <Axes: xlabel='marks2', ylabel='count'>

# %%
first_outlier=["nikita","A",-200,-1,102]
second_outlier=["Illahi","B",0,-900,1222]

# %%
df.loc[20]=first_outlier

# %%
df.loc[21]=second_outlier

# %%
df
# Out:
#        name division  marks1  marks2  marks3
# 0     Alice        A       1    60.0     5.0
# 1       Bob        B       1    70.0    60.0
# 2   Charlie        A       1    75.0    65.0
# 3     David        C       1    80.0    70.0
# 4      Emma        B       1    85.0    75.0
# 5     Frank        A       1    55.0    45.0
# 6     Grace        B       1    65.0    55.0
# 7     Henry        C       1    50.0    40.0
# 8       Ivy        B       1    40.0    30.0
# 9      Jack        A       1    75.0    65.0
# 10    Katie        C       0    80.0    70.0
# 11     Liam        B       1    45.0    35.0
# 12      Mia        A       1    70.0    60.0
# 13     Nate        C       1    60.0    50.0
# 15    Peter        A       1    30.0    20.0
# 16    Quinn        C       1    80.0    70.0
# 17   Rachel        B       1    70.0    60.0
# 19    Tyler        C       1    55.0    45.0
# 20   nikita        A    -200    -1.0   102.0
# 21   Illahi        B       0  -900.0  1222.0

# %%
sns.countplot(data=df,x=df["marks2"])
# Out:
# <Axes: xlabel='marks2', ylabel='count'>

# %%
sns.boxplot(data=df, x='marks2')
# Out:
# <Axes: xlabel='marks2'>

# %%
from matplotlib.cbook import boxplot_stats  
outliers = boxplot_stats(df['marks2']).pop(0)['fliers']
outliers
# Out:
# array([  -1., -900.])

# %%
df
# Out:
#        name division  marks1  marks2  marks3
# 0     Alice        A       1    60.0     5.0
# 1       Bob        B       1    70.0    60.0
# 2   Charlie        A       1    75.0    65.0
# 3     David        C       1    80.0    70.0
# 4      Emma        B       1    85.0    75.0
# 5     Frank        A       1    55.0    45.0
# 6     Grace        B       1    65.0    55.0
# 7     Henry        C       1    50.0    40.0
# 8       Ivy        B       1    40.0    30.0
# 9      Jack        A       1    75.0    65.0
# 10    Katie        C       0    80.0    70.0
# 11     Liam        B       1    45.0    35.0
# 12      Mia        A       1    70.0    60.0
# 13     Nate        C       1    60.0    50.0
# 15    Peter        A       1    30.0    20.0
# 16    Quinn        C       1    80.0    70.0
# 17   Rachel        B       1    70.0    60.0
# 19    Tyler        C       1    55.0    45.0
# 20   nikita        A    -200    -1.0   102.0
# 21   Illahi        B       0  -900.0  1222.0

# %%
df.drop(20)
# Out:
#        name division  marks1  marks2  marks3
# 0     Alice        A       1    60.0     5.0
# 1       Bob        B       1    70.0    60.0
# 2   Charlie        A       1    75.0    65.0
# 3     David        C       1    80.0    70.0
# 4      Emma        B       1    85.0    75.0
# 5     Frank        A       1    55.0    45.0
# 6     Grace        B       1    65.0    55.0
# 7     Henry        C       1    50.0    40.0
# 8       Ivy        B       1    40.0    30.0
# 9      Jack        A       1    75.0    65.0
# 10    Katie        C       0    80.0    70.0
# 11     Liam        B       1    45.0    35.0
# 12      Mia        A       1    70.0    60.0
# 13     Nate        C       1    60.0    50.0
# 15    Peter        A       1    30.0    20.0
# 16    Quinn        C       1    80.0    70.0
# 17   Rachel        B       1    70.0    60.0
# 19    Tyler        C       1    55.0    45.0
# 21   Illahi        B       0  -900.0  1222.0

# %%
df.drop([19,21])
# Out:
#        name division  marks1  marks2  marks3
# 0     Alice        A       1    60.0     5.0
# 1       Bob        B       1    70.0    60.0
# 2   Charlie        A       1    75.0    65.0
# 3     David        C       1    80.0    70.0
# 4      Emma        B       1    85.0    75.0
# 5     Frank        A       1    55.0    45.0
# 6     Grace        B       1    65.0    55.0
# 7     Henry        C       1    50.0    40.0
# 8       Ivy        B       1    40.0    30.0
# 9      Jack        A       1    75.0    65.0
# 10    Katie        C       0    80.0    70.0
# 11     Liam        B       1    45.0    35.0
# 12      Mia        A       1    70.0    60.0
# 13     Nate        C       1    60.0    50.0
# 15    Peter        A       1    30.0    20.0
# 16    Quinn        C       1    80.0    70.0
# 17   Rachel        B       1    70.0    60.0
# 20   nikita        A    -200    -1.0   102.0

# %%
df.drop([20])
# Out:
#        name division  marks1  marks2  marks3
# 0     Alice        A       1    60.0     5.0
# 1       Bob        B       1    70.0    60.0
# 2   Charlie        A       1    75.0    65.0
# 3     David        C       1    80.0    70.0
# 4      Emma        B       1    85.0    75.0
# 5     Frank        A       1    55.0    45.0
# 6     Grace        B       1    65.0    55.0
# 7     Henry        C       1    50.0    40.0
# 8       Ivy        B       1    40.0    30.0
# 9      Jack        A       1    75.0    65.0
# 10    Katie        C       0    80.0    70.0
# 11     Liam        B       1    45.0    35.0
# 12      Mia        A       1    70.0    60.0
# 13     Nate        C       1    60.0    50.0
# 15    Peter        A       1    30.0    20.0
# 16    Quinn        C       1    80.0    70.0
# 17   Rachel        B       1    70.0    60.0
# 19    Tyler        C       1    55.0    45.0
# 21   Illahi        B       0  -900.0  1222.0

# %%
df = df.drop([20,21,19], axis=0)

# %%
df
# Out:
#        name division  marks1  marks2  marks3
# 0     Alice        A       1    60.0     5.0
# 1       Bob        B       1    70.0    60.0
# 2   Charlie        A       1    75.0    65.0
# 3     David        C       1    80.0    70.0
# 4      Emma        B       1    85.0    75.0
# 5     Frank        A       1    55.0    45.0
# 6     Grace        B       1    65.0    55.0
# 7     Henry        C       1    50.0    40.0
# 8       Ivy        B       1    40.0    30.0
# 9      Jack        A       1    75.0    65.0
# 10    Katie        C       0    80.0    70.0
# 11     Liam        B       1    45.0    35.0
# 12      Mia        A       1    70.0    60.0
# 13     Nate        C       1    60.0    50.0
# 15    Peter        A       1    30.0    20.0
# 16    Quinn        C       1    80.0    70.0
# 17   Rachel        B       1    70.0    60.0

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
scaler=MinMaxScaler()
df["marks3"]=scaler.fit_transform(df[["marks3"]]);

# %%
df
# Out:
#        name division  marks1  marks2    marks3
# 0     Alice        A       1    60.0  0.000000
# 1       Bob        B       1    70.0  0.785714
# 2   Charlie        A       1    75.0  0.857143
# 3     David        C       1    80.0  0.928571
# 4      Emma        B       1    85.0  1.000000
# 5     Frank        A       1    55.0  0.571429
# 6     Grace        B       1    65.0  0.714286
# 7     Henry        C       1    50.0  0.500000
# 8       Ivy        B       1    40.0  0.357143
# 9      Jack        A       1    75.0  0.857143
# 10    Katie        C       0    80.0  0.928571
# 11     Liam        B       1    45.0  0.428571
# 12      Mia        A       1    70.0  0.785714
# 13     Nate        C       1    60.0  0.642857
# 15    Peter        A       1    30.0  0.214286
# 16    Quinn        C       1    80.0  0.928571
# 17   Rachel        B       1    70.0  0.785714
